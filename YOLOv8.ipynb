# %% [markdown]
# <a href="https://colab.research.google.com/github/taramatin/obj_detection/blob/main/YOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# mount google drive on colab

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Install Dependencies

# %%
# !pip install -U ultralytics
# !python -m pip install --upgrade pip
# !pip install tensorflow
# !pip install tensorboard
# !pip install torch torchvision torchaudio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.0/899.0 kB 31.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 30.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...

# %% [markdown]
# Change ROOT_DIR

# %%
ROOT_DIR = 'path/to/directory/you/want/to/be/your/root/directory'

# %% [markdown]
# Change Directory

# %%
# %cd {ROOT_DIR}
# Out:
# /content/gdrive/MyDrive/computer_vision/yolov8

# %% [markdown]
# Clone Repo

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 45653, done.
# remote: Counting objects: 100% (918/918), done.
# remote: Compressing objects: 100% (585/585), done.
# remote: Total 45653 (delta 596), reused 547 (delta 325), pack-reused 44735 (from 1)
# Receiving objects: 100% (45653/45653), 38.90 MiB | 15.40 MiB/s, done.
# Resolving deltas: 100% (33836/33836), done.
# Updating files: 100% (677/677), done.

# %% [markdown]
# Change Directory

# %%
# %cd ultralytics
# Out:
# /content/gdrive/MyDrive/computer_vision/yolov8/ultralytics

# %% [markdown]
# Train!

# %%
# !yolo help
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#
#     Arguments received: ['yolo', 'help']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of {'classify', 'obb', 'pose', 'detect', 'segment'}
#                 MODE (required) is one of {'val', 'benchmark', 'track', 'train', 'export', 'predict'}
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
#                     See all ARGS at https://docs.ultralytics.com/usage/cfg or with 'yolo cfg'
#
#     1. Train a detection model for 10 epochs with an initial learning_rate of 0.01
# ...

# %%
# !yolo task=detect mode=train model=your_model.pt data=path/to/your/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.50 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Test

# %%
# !yolo task=detect mode=predict model=path/to/your/best.pt source=path/to/your/test.jpg
# Out:
# Ultralytics 8.3.50 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/gdrive/MyDrive/computer_vision/yolov8/dataset/test.jpg: 640x640 1 left hand, 8.7ms
# Speed: 4.6ms preprocess, 8.7ms inference, 549.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image

# %%
Image('path/to/your/test.jpg')
